# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Leitura e Tratamento dos Datasets

# %%
directory = '../data/'
filename_2020_part1 = 'HIST_PAINEL_COVIDBR_2020_Parte1_04mai2022.csv'
filename_2020_part2 = 'HIST_PAINEL_COVIDBR_2020_Parte2_04mai2022.csv'
filename_2021_part1 = 'HIST_PAINEL_COVIDBR_2021_Parte1_04mai2022.csv'
filename_2021_part2 = 'HIST_PAINEL_COVIDBR_2021_Parte2_04mai2022.csv'
filename_2022_part1 = 'HIST_PAINEL_COVIDBR_2022_Parte1_04mai2022.csv'



df1 = pd.read_csv(directory+filename_2020_part1, sep=';')
df2 = pd.read_csv(directory+filename_2020_part2, sep=';')
df3 = pd.read_csv(directory+filename_2021_part1, sep=';')
df4 = pd.read_csv(directory+filename_2021_part2, sep=';')
df5 = pd.read_csv(directory+filename_2022_part1, sep=';')

# %%
df = pd.concat([df1, df2, df3, df4, df5])
df
# Out:
#               regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 0             Brasil    NaN       NaN     76       NaN             NaN
# 1             Brasil    NaN       NaN     76       NaN             NaN
# 2             Brasil    NaN       NaN     76       NaN             NaN
# 3             Brasil    NaN       NaN     76       NaN             NaN
# 4             Brasil    NaN       NaN     76       NaN             NaN
# ...              ...    ...       ...    ...       ...             ...
# 696753  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 696754  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 696755  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 696756  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 696757  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#          nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...

# %%
# df = df.sort_values(by='data')
# df
df.isnull().sum()
# Out:
# regiao                          0
# estado                       1103
# municipio                   38852
# coduf                           0
# codmun                      22703
# codRegiaoSaude              38852
# nomeRegiaoSaude             38852
# data                            0
# semanaEpi                       0
# populacaoTCU2019            16149
# casosAcumulado                  0
# casosNovos                      0
# obitosAcumulado                 0
# obitosNovos                     0
# Recuperadosnovos          4321079
# emAcompanhamentoNovos     4321079
# interior/metropolitana      38852
# dtype: int64

# %%
df = df.reset_index().drop(['index'], axis=1)
df
# Out:
#                regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 0              Brasil    NaN       NaN     76       NaN             NaN
# 1              Brasil    NaN       NaN     76       NaN             NaN
# 2              Brasil    NaN       NaN     76       NaN             NaN
# 3              Brasil    NaN       NaN     76       NaN             NaN
# 4              Brasil    NaN       NaN     76       NaN             NaN
# ...               ...    ...       ...    ...       ...             ...
# 4322177  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 4322178  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 4322179  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 4322180  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 4322181  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#           nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...

# %% [markdown]
# ## Medidas de Centralidade

# %%
df.mean(numeric_only=True)
# Out:
# coduf                     3.236313e+01
# codmun                    3.252580e+05
# codRegiaoSaude            3.240312e+04
# semanaEpi                 2.625778e+01
# populacaoTCU2019          1.304015e+05
# casosAcumulado            7.990802e+03
# casosNovos                2.117160e+01
# obitosAcumulado           2.102692e+02
# obitosNovos               4.607110e-01
# Recuperadosnovos          1.117270e+07
# emAcompanhamentoNovos     7.060629e+05
# interior/metropolitana    6.929982e-02
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# coduf                           31.0
# codmun                      314610.0
# codRegiaoSaude               31059.0
# semanaEpi                       26.0
# populacaoTCU2019             11695.0
# casosAcumulado                 468.0
# casosNovos                       0.0
# obitosAcumulado                  9.0
# obitosNovos                      0.0
# Recuperadosnovos          10000980.0
# emAcompanhamentoNovos       690587.0
# interior/metropolitana           0.0
# dtype: float64

# %%
df.mode(numeric_only=True)
# Out:
#       coduf    codmun  codRegiaoSaude  semanaEpi  populacaoTCU2019  \
# 0      31.0  110000.0         22009.0       17.0            5237.0
# 1       NaN  110001.0             NaN        NaN               NaN
# 2       NaN  110002.0             NaN        NaN               NaN
# 3       NaN  110003.0             NaN        NaN               NaN
# 4       NaN  110004.0             NaN        NaN               NaN
# ...     ...       ...             ...        ...               ...
# 5586    NaN  522200.0             NaN        NaN               NaN
# 5587    NaN  522205.0             NaN        NaN               NaN
# 5588    NaN  522220.0             NaN        NaN               NaN
# 5589    NaN  522230.0             NaN        NaN               NaN
# 5590    NaN  530010.0             NaN        NaN               NaN
#
#       casosAcumulado  casosNovos  obitosAcumulado  obitosNovos  \
# 0                0.0         0.0              0.0          0.0
# ...

# %% [markdown]
# ## Medidas de Dispersão

# %%
df.var(numeric_only=True)
# Out:
# coduf                     9.763642e+01
# codmun                    9.709153e+09
# codRegiaoSaude            9.675363e+07
# semanaEpi                 2.248749e+02
# populacaoTCU2019          1.206264e+13
# casosAcumulado            6.337064e+10
# casosNovos                5.897405e+05
# obitosAcumulado           4.347336e+07
# obitosNovos               2.937082e+02
# Recuperadosnovos          7.611865e+13
# emAcompanhamentoNovos     2.634519e+11
# interior/metropolitana    6.449737e-02
# dtype: float64

# %%
df.std(numeric_only=True)
# Out:
# coduf                     9.881115e+00
# codmun                    9.853504e+04
# codRegiaoSaude            9.836342e+03
# semanaEpi                 1.499583e+01
# populacaoTCU2019          3.473131e+06
# casosAcumulado            2.517353e+05
# casosNovos                7.679456e+02
# obitosAcumulado           6.593433e+03
# obitosNovos               1.713792e+01
# Recuperadosnovos          8.724600e+06
# emAcompanhamentoNovos     5.132757e+05
# interior/metropolitana    2.539633e-01
# dtype: float64

# %%
df.corr()
# Out:
#                            coduf        codmun  codRegiaoSaude     semanaEpi  \
# coduf                   1.000000  9.998693e-01    9.999930e-01 -1.255291e-04
# codmun                  0.999869  1.000000e+00    9.998902e-01 -2.032363e-14
# codRegiaoSaude          0.999993  9.998902e-01    1.000000e+00 -9.384121e-15
# semanaEpi              -0.000126 -2.032363e-14   -9.384121e-15  1.000000e+00
# populacaoTCU2019        0.068152 -2.372734e-03   -2.572671e-03 -3.052611e-03
# casosAcumulado          0.056710  1.657459e-02    1.652714e-02 -4.296491e-03
# casosNovos              0.043496  8.397065e-03    8.431303e-03 -1.121064e-02
# obitosAcumulado         0.056635  8.620548e-03    8.404923e-03 -2.356773e-03
# obitosNovos             0.041743  3.704180e-03    3.647399e-03 -6.379934e-03
# Recuperadosnovos             NaN           NaN             NaN -1.740766e-02
# emAcompanhamentoNovos        NaN           NaN             NaN -3.685587e-01
# ...

# %% [markdown]
# ## Boxplot das variáveis

# %%
# for column, dtype in zip(df, df.dtypes):
#         if dtype == 'float64' or dtype == 'int64':
#                 plt.figure()
#                 df.boxplot([column])

# %% [markdown]
# ## Histograma de Casos e Óbitos

# %%
new_df = pd.DataFrame(columns=['data', 'casosNovos'])
new_df
# Out:
# Empty DataFrame
# Columns: [data, casosNovos]
# Index: []

# %%
test_df = df.copy()
test_df['data'] = pd.to_datetime(test_df['data'])
# test_df = test_df.set_index('data')
# test_df = test_df[:50]
test_df = test_df[test_df['estado'] == 'PB']

# %%
# for i in range(len(test_df['casosNovos'])):

#     if test_df['casosNovos'][i] >= 2:
#         for j in range(test_df['casosNovos'][i] - 1):
#             new_df.loc[len(new_df)] = [test_df['casosNovos'].index[i], 0]
#     else:
#         new_df.loc[len(new_df)] = [test_df['casosNovos'].index[i], 0]

# %%
# new_df

# %%
test_df[['data']]
# Out:
#               data
# 1983    2020-02-25
# 1984    2020-02-26
# 1985    2020-02-27
# 1986    2020-02-28
# 1987    2020-02-29
# ...            ...
# 3811545 2022-04-30
# 3811546 2022-05-01
# 3811547 2022-05-02
# 3811548 2022-05-03
# 3811549 2022-05-04
#
# [173056 rows x 1 columns]

# %%
plt.figure(figsize=(12,12))
# sns.barplot(x=test_df['data'], y=test_df['casosNovos'], )

plt.bar(x=test_df['data'], height=test_df['casosNovos'])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-2ac0e44d3c39> in <module>
#       4 plt.bar(x=test_df['data'], height=test_df['casosNovos'])
#       5
# ----> 6 plt.show()
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py in show(*args, **kwargs)
#     351     """
#     352     _warn_if_gui_out_of_main_thread()
# --> 353     return _backend_mod.show(*args, **kwargs)
#     354
#     355
#
# /usr/local/lib/python3.8/dist-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37     try:
#      38         for figure_manager in Gcf.get_all_fig_managers():
# ---> 39             display(
#      40                 figure_manager.canvas.figure,
#      41                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ...

# %%
plt.figure(figsize=(12,12))
# sns.barplot(x=test_df['data'], y=test_df['casosAcumulado'])

plt.bar(x=test_df['data'], height=test_df['casosAcumulado'])

plt.show()

# %%
plt.figure(figsize=(12,12))
# sns.barplot(x=test_df['data'], y=test_df['casosNovos'], )

plt.bar(x=test_df['data'], height=test_df['obitosNovos'])

plt.show()

# %%
plt.figure(figsize=(12,12))
# sns.barplot(x=test_df['data'], y=test_df['casosNovos'], )
# test_df = test_df[(test_df['casosAcumulado']!=0)]
# plt.bar(x=test_df['data'], height=test_df['obitosAcumulado'])
data = test_df[(test_df['obitosAcumulado']!=0)]['obitosAcumulado']
plt.bar(x=test_df[(test_df['obitosAcumulado']!=0)]['data'], height=data)



plt.show()
